# %% [markdown]
# # Major Air Pollutant Types from the Oil Refining Process
# http://www.baaqmd.gov/research-and-data/air-quality-standards-and-attainment-status
# - Ozone (O3)
# - Carbon Monoxide (CO)
# - Hydrogen Sulfide (H2S)
# - Vinyl Chloride (C2H3Cl)
#
# - Particulate Matter (PM)
# - Nitrogen Oxides (NOx)
#   - Nitrogen Dioxide (NO2)
# - Sulfur Dioxide (SO2)
# - Methane (CH4)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
all_grades = pd.read_csv("imports_clean.csv", header=0, index_col=0)
#all_grades = all_grades.drop(['Pinned Series'])

# %%
all_grades = all_grades.drop('World', axis=0)
all_grades.replace('--', np.nan).dropna(how='all');
all_grades[:5]
# Out:
#             X2009  X2010  X2011  X2012  X2013  X2014  X2015  X2016
# Algeria         0      0      0   1310     74      0      0      0
# Angola      12913   7040  11163  14931  12454  13074  14291  10545
# Argentina    4450   3523   3173   1046      0      0      0    868
# Australia     585   1033   2293   1176    523      0   1179    657
# Azerbaijan    530      0      0      0      0      0      0      0

# %%
all_grades = all_grades.sort_values(by=['X2016'])
all_grades = all_grades.T
all_grades[:5]
# Out:
#        Algeria  Trinidad and Tobago  Thailand  Mauritania  Azerbaijan  Belize  \
# X2009        0                  359      1332           0         530       0
# X2010        0                  180         0           0           0       0
# X2011        0                    0         0           0           0       0
# X2012     1310                  719         0           0           0       0
# X2013       74                    0         0         625           0       0
#
#        Bolivia  Libya  Cameroon  Italy      ...       Russia  Brazil  Canada  \
# X2009      922      0         0      0      ...          993   25560   13765
# X2010        0      0       602      0      ...        17937   22383   19268
# X2011        0      0         0      0      ...        10666   16713   11191
# X2012        0    530         0    308      ...         9528    9809   14316
# X2013        0     77         0      0      ...         5948    8570   15491
#
# ...

# %%
all_grades.plot.bar(stacked=True, legend=False);
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);
